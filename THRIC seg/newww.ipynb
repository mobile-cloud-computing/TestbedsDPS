# %%
import numpy as np
import cv2
import glob
import ntpath
import os
from PIL import Image

# %%
def flatten(seq):
  for el in seq:
    if isinstance(el, list):
      yield from flatten(el)
    else:
      yield el

# %%
filelist=glob.glob('./thermal2/*.txt')

# %%
for i in filelist:
    print(i)
    values=[]
    with open(i) as f:
        for line in f:
            linelist=line.split(" ")
            lineint=[int(i) for i in linelist]
            values.append(lineint)
        
    print(np.mean(values))
    white=max(flatten(values))
    black=min(flatten(values))
    if black!=white:
        for index,line in enumerate(values):
            for ind,v in enumerate(line):
                values[index][ind]=int((v-black)/(white-black)*255)
        im = np.array(values, dtype = np.uint8)
        print(im)

        vmin=30300
        vmax=31300
        vmint=int((vmin-black)/(white-black)*255)
        vmaxt=int((vmax-black)/(white-black)*255)

        thresh=29800
        thresht=int((thresh-black)/(white-black)*255)
        #res2 = cv2.inRange(im, 200, 255)
        res3 = cv2.inRange(im, 150, 255)
        #res4 = cv2.inRange(im, 100, 255)
        

        #im_v = cv2.hconcat([im,res2,res3,res4])
        #cv2.imshow('image',im_v)
        #cv2.imshow('image',res3)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        filename=ntpath.basename(i)
        pre=filename.split(".")[0]
        fi='./threshold-thermal2/'+pre+".png"
        cv2.imwrite(fi,res3)
        img = cv2.imread('./threshold-thermal2/'+pre+".png",0)
# Out:
# ./thermal2\1560251223589-temperatures.txt
# 30098.810364583333
# [[85 86 86 ... 92 92 92]
#  [86 86 86 ... 92 92 92]
#  [86 87 87 ... 92 92 92]
#  ...
#  [84 84 84 ... 91 92 92]
#  [84 84 84 ... 91 92 92]
#  [84 85 85 ... 91 91 92]]
# ./thermal2\1562084490444-temperatures.txt
# 29802.40947916667
# [[23 23 24 ... 29 29 29]
#  [23 23 24 ... 29 29 29]
#  [23 24 24 ... 29 29 29]
#  ...
#  [28 28 28 ... 16 16 16]
#  [28 28 28 ... 16 16 16]
#  [28 28 28 ... 16 16 17]]
# ./thermal2\1566904246700-temperatures.txt
# 21313.0
# ./thermal2\1566904247734-temperatures.txt
# 29884.850546875
# [[96 97 97 ... 89 89 89]
#  [96 96 97 ... 89 89 89]
#  [96 96 96 ... 89 89 89]
#  ...
#  [66 66 66 ... 39 39 38]
#  [66 66 66 ... 40 40 39]
#  [66 66 66 ... 41 41 40]]
# ./thermal2\1566904248818-temperatures.txt
# 29811.02162760417
# [[79 79 79 ... 80 80 80]
#  [79 79 79 ... 80 80 80]
#  [79 79 79 ... 80 80 80]
#  ...
#  [59 59 59 ... 37 36 36]
#  [58 58 58 ... 38 37 37]
#  [58 58 58 ... 40 40 40]]
# ./thermal2\1566904249897-temperatures.txt
# 29783.718294270835
# [[82 82 82 ... 80 80 80]
#  [81 82 82 ... 80 80 80]
#  [81 81 82 ... 80 80 80]
#  ...
#  [58 58 58 ... 36 35 35]
#  [58 58 58 ... 37 37 36]
#  [58 58 58 ... 40 39 39]]
# ./thermal2\1566904251145-temperatures.txt
# 29777.37274739583
# [[86 86 86 ... 79 79 79]
#  [86 86 86 ... 79 79 79]
#  [85 86 86 ... 79 79 80]
#  ...
#  [56 56 56 ... 34 33 32]
#  [56 56 56 ... 35 34 34]
#  [56 56 56 ... 37 36 36]]
# ./thermal2\1566904252164-temperatures.txt
# 29506.910625
# [[50 50 50 ... 33 32 31]
#  [50 50 50 ... 32 31 31]
#  [50 50 50 ... 31 31 30]
#  ...
#  [ 7  7  7 ... 24 24 24]
#  [ 7  7  7 ... 24 24 24]
#  [ 7  7  7 ... 24 24 24]]
# ./thermal2\1566904253246-temperatures.txt
# 29498.126002604167
# [[57 57 57 ... 27 26 26]
#  [56 57 57 ... 26 26 25]
#  [56 56 56 ... 26 25 24]
#  ...
#  [ 8  8  8 ... 26 26 25]
#  [ 8  8  8 ... 25 25 25]
#  [ 8  8  8 ... 25 25 24]]
# ./thermal2\1566904254329-temperatures.txt
# 29492.7037890625
# [[58 58 58 ... 40 39 38]
#  [58 57 58 ... 39 38 37]
#  [57 57 57 ... 38 38 37]
#  ...
#  [ 7  7  7 ... 17 20 23]
#  [ 7  7  7 ... 16 20 22]
#  [ 7  7  7 ... 16 19 22]]
# ./thermal2\1566904255369-temperatures.txt
# 29500.212096354167
# [[58 58 58 ... 27 27 26]
#  [58 58 58 ... 27 26 26]
#  [58 58 58 ... 27 26 26]
#  ...
#  [ 9  9  9 ... 27 27 27]
#  [ 9  9  9 ... 27 27 27]
#  [ 9  9  9 ... 27 27 27]]
# ./thermal2\1566904256405-temperatures.txt
# 29507.298841145832
# [[63 63 63 ... 26 25 25]
#  [63 63 63 ... 25 25 24]
#  [62 63 63 ... 25 24 24]
#  ...
#  [10 10 10 ... 31 30 30]
#  [10 10 10 ... 31 30 30]
#  [10 10 10 ... 30 30 30]]
# ./thermal2\1566904257446-temperatures.txt
# 29515.0376953125
# [[57 57 57 ... 18 18 18]
#  [57 57 57 ... 18 18 18]
#  [57 57 57 ... 17 18 18]
#  ...
#  [ 9 10 10 ... 25 25 24]
#  [ 9 10 10 ... 25 25 24]
#  [10 10 10 ... 25 25 25]]
# ./thermal2\1566904258494-temperatures.txt
# 29520.035221354166
# [[59 59 60 ... 16 16 16]
#  [59 59 59 ... 16 16 17]
#  [58 58 59 ... 16 17 17]
#  ...
#  [ 7  7  7 ... 21 21 20]
#  [ 7  7  7 ... 21 20 20]
#  [ 8  7  7 ... 20 20 20]]
# ./thermal2\1566904259531-temperatures.txt
# 29502.231328125
# [[50 50 50 ... 14 14 14]
#  [49 50 50 ... 14 14 14]
#  [49 49 49 ... 14 14 14]
#  ...
#  [ 8  8  8 ... 19 19 19]
#  [ 8  8  8 ... 19 19 19]
#  [ 8  8  8 ... 18 18 18]]
# ./thermal2\1566904260571-temperatures.txt
# 29501.6632421875
# [[62 62 62 ... 16 16 16]
#  [62 62 62 ... 16 16 16]
#  [62 62 62 ... 16 16 17]
#  ...
#  [ 9  9  9 ... 23 23 23]
#  [ 9  9  9 ... 22 22 22]
#  [ 9  9  9 ... 22 22 22]]
# ./thermal2\1566904261635-temperatures.txt
# 29498.2022265625
# [[64 64 64 ... 16 16 16]
#  [63 63 63 ... 16 16 17]
#  [63 63 63 ... 16 17 17]
#  ...
#  [10 10 10 ... 24 24 24]
#  [10 10 10 ... 24 24 24]
#  [10 10 10 ... 24 24 24]]
# ./thermal2\1566904262754-temperatures.txt
# 29485.402604166666
# [[60 60 60 ... 14 14 15]
#  [60 60 60 ... 14 14 15]
#  [60 60 60 ... 14 15 15]
#  ...
#  [ 8  8  7 ... 24 24 24]
#  [ 8  8  7 ... 24 24 24]
#  [ 8  8  7 ... 24 24 23]]
# ./thermal2\1566904263767-temperatures.txt
# 29475.1829296875
# [[60 60 60 ... 12 12 12]
#  [60 60 60 ... 12 12 12]
#  [59 59 59 ... 12 12 12]
#  ...
#  [ 9  9  9 ... 11 14 16]
#  [ 9  9  9 ... 11 13 16]
#  [ 9  9  9 ... 10 13 15]]
# ./thermal2\1566904264815-temperatures.txt
# 29465.3871484375
# [[60 60 60 ... 12 12 12]
#  [60 60 60 ... 12 13 13]
#  [60 60 60 ... 12 13 13]
#  ...
#  [10 10 10 ... 22 24 26]
#  [10 10 10 ... 21 23 25]
#  [10 10 10 ... 20 23 25]]
# ./thermal2\1566904265853-temperatures.txt
# 29462.89243489583
# [[ 54  54  55 ...   8   8   8]
#  [ 54  54  54 ...   8   8   8]
#  [ 53  54  54 ...   8   8   8]
#  ...
#  [  5   5   5 ... 112 113 113]
#  [  5   5   5 ... 111 111 112]
#  [  5   5   5 ... 108 109 109]]
# ./thermal2\1566904266932-temperatures.txt
# 29414.1869140625
# [[15 15 15 ... 16 15 15]
#  [14 15 15 ... 15 15 15]
#  [14 14 15 ... 15 15 14]
#  ...
#  [ 4  4  4 ...  1  1  1]
#  [ 4  4  4 ...  1  1  1]
#  [ 4  4  4 ...  1  1  1]]
# ./thermal2\1566904268045-temperatures.txt
# 29387.5728515625
# [[9 9 9 ... 6 7 7]
#  [9 9 9 ... 7 7 7]
#  [9 9 9 ... 7 7 7]
#  ...
#  [5 5 5 ... 1 1 1]
#  [5 5 5 ... 1 1 1]
#  [5 5 5 ... 1 1 1]]
# ./thermal2\1566904269090-temperatures.txt
# 29373.605755208333
# [[8 8 8 ... 6 6 6]
#  [8 8 8 ... 6 6 7]
#  [8 8 8 ... 6 7 7]
#  ...
#  [4 4 4 ... 2 3 3]
#  [4 4 4 ... 2 3 3]
#  [4 4 4 ... 2 2 3]]
# ./thermal2\1566904270124-temperatures.txt
# 29345.345885416667
# [[8 8 8 ... 7 7 7]
#  [8 8 8 ... 7 7 8]
#  [8 8 8 ... 8 8 8]
#  ...
#  [5 5 5 ... 1 2 2]
#  [5 5 5 ... 1 1 2]
#  [5 5 5 ... 1 1 2]]
# ./thermal2\1566904271209-temperatures.txt
# 29331.6527734375
# [[ 8  8  8 ...  6  6  6]
#  [ 8  8  8 ...  6  6  6]
#  [ 8  8  8 ...  6  6  6]
#  ...
#  [ 3  3  3 ... 13 13 14]
#  [ 3  3  3 ... 13 14 14]
#  [ 3  3  3 ... 13 14 14]]
# ./thermal2\1566904272274-temperatures.txt
# 29344.55401041667
# [[16 17 17 ... 34 33 32]
#  [16 17 17 ... 33 33 32]
#  [16 17 17 ... 33 32 31]
#  ...
#  [ 4  4  4 ...  7  9 11]
#  [ 4  4  4 ...  6  8 10]
#  [ 3  3  3 ...  6  8 10]]
# ./thermal2\1566904273324-temperatures.txt
# 29326.1276953125
# [[16 16 17 ... 25 24 23]
#  [16 16 17 ... 25 24 23]
#  [16 16 17 ... 24 23 22]
#  ...
#  [ 4  4  4 ...  2  3  4]
#  [ 4  4  4 ...  2  3  4]
#  [ 4  4  4 ...  2  3  4]]
# ./thermal2\1566904275292-temperatures.txt
# 29670.02178385417
# [[18 18 18 ... 46 46 46]
#  [18 18 18 ... 46 46 46]
#  [18 18 18 ... 46 46 46]
#  ...
#  [ 7  7  7 ...  3  3  3]
#  [ 7  7  7 ...  3  3  3]
#  [ 7  7  7 ...  3  4  4]]
# ./thermal2\1566904276332-temperatures.txt
# 29652.955677083333
# [[14 14 14 ... 48 48 47]
#  [13 13 14 ... 48 48 47]
#  [13 13 13 ... 48 47 47]
#  ...
#  [ 6  6  6 ...  3  3  3]
#  [ 6  6  6 ...  3  3  3]
#  [ 6  6  6 ...  3  3  3]]
# ./thermal2\1566904277374-temperatures.txt
# 29644.525299479166
# [[16 16 16 ... 33 33 32]
#  [15 15 15 ... 33 32 31]
#  [15 15 15 ... 32 31 31]
#  ...
#  [ 7  7  7 ...  2  2  2]
#  [ 7  7  7 ...  2  2  2]
#  [ 7  7  7 ...  2  2  2]]
# ./thermal2\1566904278428-temperatures.txt
# 29648.070091145833
# [[18 18 18 ... 30 29 28]
#  [18 18 18 ... 29 28 27]
#  [18 18 18 ... 28 27 26]
#  ...
#  [ 7  7  7 ...  3  3  3]
#  [ 7  7  7 ...  3  3  3]
#  [ 7  7  7 ...  2  2  3]]
# ./thermal2\1566904279495-temperatures.txt
# 29661.178671875
# [[23 23 23 ... 26 25 25]
#  [22 22 22 ... 25 25 25]
#  [22 22 22 ... 25 25 24]
#  ...
#  [ 8  8  7 ...  3  3  3]
#  [ 8  8  7 ...  3  3  3]
#  [ 7  7  7 ...  3  3  3]]
# ./thermal2\1566904280533-temperatures.txt
# 29671.583828125
# [[19 19 19 ... 16 16 16]
#  [19 19 19 ... 16 16 15]
#  [19 19 19 ... 16 15 15]
#  ...
#  [ 5  5  5 ...  9 11 12]
#  [ 5  5  5 ...  9 11 12]
#  [ 5  5  5 ...  9 10 11]]
# ./thermal2\1566904281573-temperatures.txt
# 29673.888489583333
# [[24 24 24 ... 32 32 31]
#  [24 24 24 ... 31 30 30]
#  [23 23 23 ... 30 30 29]
#  ...
#  [10  9  9 ...  8  8  9]
#  [10 10  9 ...  8  8  8]
#  [10 10  9 ...  8  8  8]]
# ./thermal2\1566904282578-temperatures.txt
# 29678.729739583334
# [[19 19 19 ... 26 25 25]
#  [18 18 19 ... 25 25 24]
#  [18 18 18 ... 25 25 24]
#  ...
#  [ 7  7  7 ...  3  4  4]
#  [ 7  7  7 ...  3  3  4]
#  [ 7  7  7 ...  3  3  4]]
# ./thermal2\1566904283625-temperatures.txt
# 29680.977955729166
# [[20 20 20 ... 25 24 24]
#  [19 19 19 ... 24 24 24]
#  [19 19 19 ... 24 24 23]
#  ...
#  [ 7  7  7 ...  2  2  3]
#  [ 7  7  7 ...  2  2  3]
#  [ 7  7  7 ...  2  2  3]]
# ./thermal2\1566904284664-temperatures.txt
# 29684.154388020834
# [[19 19 19 ... 25 25 24]
#  [19 19 19 ... 25 25 24]
#  [19 19 19 ... 25 24 24]
#  ...
#  [ 8  8  8 ...  4  4  4]
#  [ 8  8  8 ...  4  4  4]
#  [ 8  8  8 ...  4  4  4]]
# ./thermal2\1566904285738-temperatures.txt
# 29691.489296875
# [[23 23 23 ... 23 23 23]
#  [23 23 23 ... 23 23 22]
#  [23 23 23 ... 22 22 22]
#  ...
#  [ 9  9  9 ...  3  3  4]
#  [ 9  9  9 ...  3  4  4]
#  [ 9  9  9 ...  3  4  4]]
# ./thermal2\1566904286779-temperatures.txt
# 29685.3359765625
# [[20 20 20 ... 20 20 20]
#  [20 20 20 ... 20 20 20]
#  [20 20 20 ... 20 20 19]
#  ...
#  [ 8  8  8 ...  3  3  3]
#  [ 8  8  8 ...  3  3  3]
#  [ 8  8  8 ...  3  3  3]]
# ./thermal2\1566904287858-temperatures.txt
# 29678.31171875
# [[21 21 21 ... 19 19 19]
#  [21 21 21 ... 19 19 18]
#  [20 20 21 ... 19 18 18]
#  ...
#  [ 7  7  7 ...  2  3  3]
#  [ 7  7  7 ...  2  2  3]
#  [ 7  7  7 ...  2  2  3]]
# ./thermal2\1566904288903-temperatures.txt
# 30450.492421875
# [[250 250 250 ... 253 253 253]
#  [250 250 250 ... 253 253 253]
#  [250 250 250 ... 253 253 253]
#  ...
#  [  9   8   8 ... 188 191 194]
#  [  9   8   8 ... 185 189 192]
#  [  8   8   8 ... 182 185 189]]
# ./thermal2\1566904289936-temperatures.txt
# 29890.765520833334
# [[  7   7   7 ...   3   3   3]
#  [  7   7   7 ...   3   3   3]
#  [  7   7   7 ...   3   3   3]
#  ...
#  [  6   6   5 ... 222 223 224]
#  [  6   6   5 ... 221 221 222]
#  [  6   6   5 ... 219 220 221]]
# ./thermal2\1566904331042-temperatures.txt
# 29890.765520833334
# [[  7   7   7 ...   3   3   3]
#  [  7   7   7 ...   3   3   3]
#  [  7   7   7 ...   3   3   3]
#  ...
#  [  6   6   5 ... 222 223 224]
#  [  6   6   5 ... 221 221 222]
#  [  6   6   5 ... 219 220 221]]
# ./thermal2\1566904332085-temperatures.txt
# 29108.0344921875
# [[11 10 10 ... 11 12 12]
#  [11 11 10 ... 12 12 12]
#  [11 11 11 ... 12 12 12]
#  ...
#  [ 2  4  5 ... 26 25 25]
#  [ 3  5  6 ... 26 26 25]
#  [ 4  6  7 ... 26 26 26]]
# ./thermal2\1566904333134-temperatures.txt
# 28872.4969921875
# [[ 6  7  7 ...  5  5  5]
#  [ 7  7  7 ...  5  5  5]
#  [ 7  7  8 ...  6  5  5]
#  ...
#  [ 2  4  6 ... 19 19 18]
#  [ 2  4  6 ... 19 19 18]
#  [ 2  4  6 ... 19 19 18]]
# ./thermal2\1566904334172-temperatures.txt
# 28702.9440234375
# [[6 6 7 ... 5 5 5]
#  [6 7 7 ... 6 6 6]
#  [7 7 7 ... 6 6 6]
#  ...
#  [0 0 1 ... 5 3 3]
#  [0 1 1 ... 4 3 3]
#  [0 1 2 ... 4 3 2]]
# ./thermal2\1566904335427-temperatures.txt
# 28637.106328125
# [[ 8  9 10 ... 17 17 16]
#  [ 8  9 10 ... 17 17 17]
#  [ 8  9 10 ... 17 17 17]
#  ...
#  [ 0  1  2 ... 32 31 29]
#  [ 0  1  1 ... 31 30 29]
#  [ 0  0  1 ... 31 29 28]]
# ./thermal2\1566904336442-temperatures.txt
# 29317.883307291668
# [[26 26 26 ... 26 27 27]
#  [26 26 26 ... 26 27 27]
#  [25 26 26 ... 26 27 27]
#  ...
#  [34 35 35 ... 39 39 40]
#  [35 35 36 ... 38 39 39]
#  [35 35 36 ... 38 38 39]]
# ./thermal2\1566904337481-temperatures.txt
# 29218.677109375
# [[24 24 24 ... 23 23 24]
#  [24 24 24 ... 23 24 24]
#  [24 24 24 ... 23 24 24]
#  ...
#  [34 34 34 ... 22 22 22]
#  [34 34 34 ... 22 22 22]
#  [34 34 34 ... 22 22 22]]
# ./thermal2\1566904338525-temperatures.txt
# 29151.575403645835
# [[24 24 24 ... 25 26 26]
#  [24 24 24 ... 25 26 26]
#  [24 24 24 ... 25 26 26]
#  ...
#  [32 32 32 ... 21 21 21]
#  [32 32 32 ... 21 21 21]
#  [32 32 32 ... 21 21 21]]
# ./thermal2\1566904339565-temperatures.txt
# 29101.358229166668
# [[26 27 27 ... 25 26 26]
#  [26 27 27 ... 25 26 26]
#  [26 27 27 ... 25 26 26]
#  ...
#  [28 28 28 ... 19 19 19]
#  [28 28 28 ... 19 19 19]
#  [28 28 28 ... 19 19 19]]
# ./thermal2\1566904340605-temperatures.txt
# 29061.170950520835
# [[26 26 26 ... 25 26 26]
#  [26 26 26 ... 25 26 26]
#  [26 26 26 ... 25 26 26]
#  ...
#  [27 27 27 ... 19 19 19]
#  [26 27 27 ... 18 18 18]
#  [26 26 26 ... 18 18 18]]
# ./thermal2\1566904341650-temperatures.txt
# 29025.263098958334
# [[25 25 26 ... 23 24 24]
#  [25 26 26 ... 23 24 24]
#  [25 26 26 ... 23 24 24]
#  ...
#  [29 29 29 ... 18 18 18]
#  [29 29 29 ... 18 18 18]
#  [28 29 29 ... 18 17 17]]
# ./thermal2\1566904342652-temperatures.txt
# 29000.717434895832
# [[24 25 25 ... 22 23 23]
#  [25 25 25 ... 22 23 23]
#  [25 25 25 ... 22 23 23]
#  ...
#  [24 24 25 ... 16 16 16]
#  [24 24 24 ... 16 16 16]
#  [24 24 24 ... 15 16 16]]
# ./thermal2\1566904343691-temperatures.txt
# 28972.621692708333
# [[24 24 24 ... 20 21 21]
#  [24 24 25 ... 20 21 21]
#  [24 25 25 ... 20 21 21]
#  ...
#  [26 26 27 ... 16 16 16]
#  [26 26 27 ... 16 16 16]
#  [26 26 26 ... 16 16 16]]
# ./thermal2\1566904344692-temperatures.txt
# 28920.096666666668
# [[20 21 21 ... 18 19 20]
#  [20 21 22 ... 19 20 20]
#  [20 21 22 ... 19 20 20]
#  ...
#  [24 24 25 ... 18 17 17]
#  [24 24 24 ... 17 17 17]
#  [24 24 24 ... 17 17 16]]
# ./thermal2\1566904345736-temperatures.txt
# 28883.446901041665
# [[19 20 21 ... 19 20 20]
#  [19 20 21 ... 19 20 20]
#  [19 20 21 ... 19 20 20]
#  ...
#  [23 23 23 ... 16 16 15]
#  [23 23 23 ... 16 15 15]
#  [23 23 23 ... 15 15 15]]
# ./thermal2\1566904347539-temperatures.txt
# 29587.8073828125
# [[26 26 25 ... 27 27 28]
#  [26 26 26 ... 27 27 28]
#  [27 27 27 ... 27 27 28]
#  ...
#  [43 43 43 ... 28 28 28]
#  [43 43 43 ... 28 28 28]
#  [43 43 43 ... 28 28 29]]
# ./thermal2\1566904348589-temperatures.txt
# 29566.192434895835
# [[26 26 26 ... 23 24 24]
#  [26 26 26 ... 23 24 24]
#  [26 26 26 ... 23 24 24]
#  ...
#  [39 38 38 ... 25 25 25]
#  [39 38 38 ... 25 25 25]
#  [39 39 38 ... 25 25 25]]
# ./thermal2\1566904349626-temperatures.txt
# 29549.821497395835
# [[27 27 27 ... 26 26 26]
#  [27 27 27 ... 25 25 26]
#  [27 27 27 ... 25 25 26]
#  ...
#  [38 38 38 ... 23 23 23]
#  [38 38 38 ... 23 23 23]
#  [38 38 38 ... 23 23 23]]
# ./thermal2\1566904350687-temperatures.txt
# 29548.049348958335
# [[31 32 32 ... 31 31 31]
#  [31 31 31 ... 31 31 32]
#  [31 31 31 ... 31 31 32]
#  ...
#  [42 42 42 ... 24 24 24]
#  [42 42 42 ... 24 24 24]
#  [42 42 42 ... 24 24 24]]
# ./thermal2\1566904351708-temperatures.txt
# 29552.305950520833
# [[31 31 31 ... 30 30 30]
#  [31 31 31 ... 29 30 30]
#  [31 31 31 ... 29 30 30]
#  ...
#  [41 41 41 ... 26 26 26]
#  [41 41 41 ... 26 26 26]
#  [41 41 41 ... 26 26 26]]
# ./thermal2\1566904352746-temperatures.txt
# 29557.352864583332
# [[33 33 33 ... 32 32 32]
#  [32 32 32 ... 32 32 32]
#  [32 32 32 ... 31 31 32]
#  ...
#  [40 40 41 ... 25 25 25]
#  [40 40 41 ... 25 25 25]
#  [41 41 41 ... 25 25 25]]
# ./thermal2\1566904353826-temperatures.txt
# 29559.99703125
# [[38 38 38 ... 37 38 38]
#  [38 38 38 ... 37 38 38]
#  [38 38 38 ... 37 38 38]
#  ...
#  [41 41 41 ... 26 26 27]
#  [41 41 41 ... 26 26 27]
#  [41 41 41 ... 26 26 26]]
# ./thermal2\1566904354905-temperatures.txt
# 29563.8657421875
# [[38 38 38 ... 37 37 37]
#  [38 38 38 ... 37 37 37]
#  [38 38 38 ... 36 37 37]
#  ...
#  [43 43 43 ... 28 28 28]
#  [43 43 43 ... 28 28 28]
#  [43 43 43 ... 28 28 28]]
# ./thermal2\1566904355946-temperatures.txt
# 29542.820963541668
# [[32 32 32 ... 31 31 31]
#  [32 32 32 ... 31 31 31]
#  [32 32 32 ... 31 31 31]
#  ...
#  [39 39 39 ... 24 24 24]
#  [39 39 39 ... 24 24 24]
#  [39 39 39 ... 24 24 24]]
# ./thermal2\1566904357012-temperatures.txt
# 29539.300325520835
# [[35 35 35 ... 33 33 33]
#  [34 34 34 ... 32 33 33]
#  [34 34 34 ... 32 33 33]
#  ...
#  [40 40 40 ... 24 24 25]
#  [40 40 40 ... 24 24 25]
#  [40 40 40 ... 24 24 24]]
# ./thermal2\1566904358087-temperatures.txt
# 29535.080833333333
# [[33 33 32 ... 30 30 30]
#  [32 32 32 ... 30 30 30]
#  [32 32 32 ... 30 30 30]
#  ...
#  [37 37 37 ... 22 22 22]
#  [37 37 37 ... 22 22 22]
#  [37 37 37 ... 22 22 22]]
# ./thermal2\1566904359108-temperatures.txt
# 29527.626484375
# [[32 32 32 ... 29 29 29]
#  [32 32 32 ... 29 29 29]
#  [32 32 32 ... 29 29 29]
#  ...
#  [40 40 40 ... 24 25 25]
#  [40 40 40 ... 24 24 25]
#  [40 40 40 ... 24 24 24]]
# ./thermal2\1566904360149-temperatures.txt
# 29517.7208203125
# [[30 30 30 ... 27 27 27]
#  [30 30 30 ... 27 27 27]
#  [30 30 30 ... 27 27 27]
#  ...
#  [38 38 38 ... 23 24 24]
#  [38 38 38 ... 23 24 24]
#  [38 38 38 ... 23 24 24]]
# ./thermal2\1566904361225-temperatures.txt
# 29514.173815104168
# [[30 30 30 ... 30 30 30]
#  [30 30 30 ... 29 30 30]
#  [30 30 30 ... 29 30 30]
#  ...
#  [39 39 39 ... 25 25 25]
#  [39 39 39 ... 25 25 25]
#  [39 39 39 ... 25 25 25]]
# ./thermal2\1566904362265-temperatures.txt
# 29503.284244791666
# [[28 28 28 ... 27 27 28]
#  [28 28 28 ... 27 27 28]
#  [28 28 28 ... 27 27 28]
#  ...
#  [37 37 37 ... 21 22 22]
#  [37 37 37 ... 21 22 22]
#  [37 37 37 ... 21 21 21]]
# ./thermal2\1566904363347-temperatures.txt
# 29497.434895833332
# [[29 29 30 ... 23 23 23]
#  [28 29 29 ... 23 23 23]
#  [28 29 29 ... 23 23 23]
#  ...
#  [38 38 38 ... 22 22 22]
#  [38 38 38 ... 22 22 22]
#  [38 38 38 ... 22 22 22]]
# ./thermal2\1566904364424-temperatures.txt
# 29483.252486979167
# [[27 27 27 ... 26 27 27]
#  [27 27 27 ... 27 27 27]
#  [27 27 27 ... 27 27 27]
#  ...
#  [41 41 41 ... 25 25 26]
#  [41 41 41 ... 25 25 26]
#  [41 41 41 ... 25 26 26]]
# ./thermal2\1566904365507-temperatures.txt
# 29473.93625
# [[24 24 24 ... 22 23 23]
#  [24 24 24 ... 22 23 23]
#  [24 24 24 ... 22 23 23]
#  ...
#  [36 36 36 ... 21 22 22]
#  [36 36 36 ... 21 22 22]
#  [36 36 36 ... 22 22 22]]
# ./thermal2\1566904366544-temperatures.txt
# 29445.5717578125
# [[21 21 21 ... 19 19 20]
#  [21 21 21 ... 19 19 20]
#  [21 21 21 ... 19 20 20]
#  ...
#  [35 35 35 ... 20 21 21]
#  [35 35 35 ... 20 21 21]
#  [35 35 35 ... 20 21 21]]
# ./thermal2\1566904368520-temperatures.txt
# 29681.5957421875
# [[29 29 29 ... 29 30 30]
#  [28 28 28 ... 30 30 30]
#  [28 27 27 ... 30 30 30]
#  ...
#  [36 36 37 ... 26 26 26]
#  [37 37 37 ... 26 26 26]
#  [37 37 37 ... 26 26 26]]
# ./thermal2\1566904369549-temperatures.txt
# 29669.8819921875
# [[24 24 23 ... 25 25 25]
#  [23 24 23 ... 24 24 25]
#  [23 24 23 ... 24 24 25]
#  ...
#  [34 34 34 ... 23 24 24]
#  [34 34 34 ... 23 24 24]
#  [34 34 34 ... 23 24 24]]
# ./thermal2\1566904370603-temperatures.txt
# 29668.0376953125
# [[24 24 24 ... 24 24 24]
#  [24 24 24 ... 24 24 24]
#  [24 24 24 ... 24 24 24]
#  ...
#  [37 37 37 ... 26 26 26]
#  [37 37 37 ... 26 26 26]
#  [37 37 37 ... 26 26 26]]
# ./thermal2\1566904371673-temperatures.txt
# 29674.006966145833
# [[25 24 24 ... 27 28 28]
#  [25 24 24 ... 27 27 27]
#  [25 24 24 ... 27 27 27]
#  ...
#  [36 36 36 ... 26 26 26]
#  [36 36 36 ... 26 26 26]
#  [36 36 36 ... 26 26 26]]
# ./thermal2\1566904372724-temperatures.txt
# 29725.014466145833
# [[17 17 17 ... 17 17 17]
#  [17 17 16 ... 17 17 17]
#  [17 17 16 ... 17 17 17]
#  ...
#  [31 31 31 ... 16 16 16]
#  [31 31 31 ... 16 16 16]
#  [31 31 31 ... 16 16 16]]
# ./thermal2\1566904373818-temperatures.txt
# 29693.620729166665
# [[188 188 184 ... 248 251 255]
#  [188 188 184 ... 245 251 251]
#  [188 188 181 ... 245 248 251]
#  ...
#  [159 159 156 ... 153 153 153]
#  [159 159 156 ... 153 153 153]
#  [159 159 156 ... 156 156 156]]
# ./thermal2\1566904374866-temperatures.txt
# 29754.127760416668
# [[24 24 23 ... 20 20 20]
#  [23 23 23 ... 20 20 20]
#  [23 23 23 ... 19 20 20]
#  ...
#  [27 27 27 ... 17 17 17]
#  [27 27 27 ... 17 17 17]
#  [27 27 26 ... 17 17 17]]
# ./thermal2\1566904375959-temperatures.txt
# 29722.969739583332
# [[66 66 66 ... 70 71 71]
#  [65 66 66 ... 70 70 71]
#  [65 66 66 ... 70 70 70]
#  ...
#  [20 19 19 ... 61 61 61]
#  [20 19 19 ... 61 61 61]
#  [20 20 20 ... 61 61 61]]
# ./thermal2\1566904377010-temperatures.txt
# 29727.655104166668
# [[90 90 90 ... 94 94 94]
#  [90 90 90 ... 92 92 92]
#  [90 90 90 ... 92 92 92]
#  ...
#  [44 44 44 ... 82 82 82]
#  [42 42 42 ... 82 82 82]
#  [41 41 39 ... 82 82 82]]
# ./thermal2\1566904378028-temperatures.txt
# 29722.423984375
# [[84 84 83 ... 81 83 84]
#  [84 84 81 ... 81 83 84]
#  [84 83 81 ... 80 81 84]
#  ...
#  [95 97 98 ... 84 84 84]
#  [93 94 94 ... 84 84 84]
#  [91 91 92 ... 84 84 84]]
# ./thermal2\1566904379074-temperatures.txt
# 29722.1337109375
# [[74 74 74 ... 77 78 78]
#  [74 74 74 ... 77 78 78]
#  [74 74 74 ... 77 78 78]
#  ...
#  [97 97 97 ... 66 66 66]
#  [97 97 97 ... 66 66 66]
#  [97 97 97 ... 66 66 66]]
# ./thermal2\1566904380108-temperatures.txt
# 29721.060416666667
# [[73 72 72 ... 70 72 73]
#  [73 72 72 ... 70 72 73]
#  [73 72 72 ... 70 72 73]
#  ...
#  [83 78 72 ... 63 63 63]
#  [83 77 72 ... 63 63 63]
#  [83 77 72 ... 63 64 64]]
# ./thermal2\1566904381149-temperatures.txt
# 29720.3948828125
# [[66 66 66 ... 75 77 77]
#  [65 65 65 ... 75 75 77]
#  [65 65 65 ... 74 75 77]
#  ...
#  [24 22 20 ... 55 55 55]
#  [24 21 18 ... 55 55 55]
#  [23 21 18 ... 55 55 55]]
# ./thermal2\1566904382199-temperatures.txt
# 29715.398893229165
# [[85 85 84 ... 91 92 93]
#  [85 85 84 ... 91 92 93]
#  [85 85 84 ... 91 92 93]
#  ...
#  [29 28 28 ... 78 78 78]
#  [29 29 28 ... 78 78 78]
#  [29 29 28 ... 78 78 78]]
# ./thermal2\1566904383239-temperatures.txt
# 29712.2925390625
# [[64 64 63 ... 68 69 69]
#  [65 64 63 ... 68 69 70]
#  [65 64 63 ... 68 69 70]
#  ...
#  [60 55 51 ... 63 63 63]
#  [60 54 49 ... 63 63 63]
#  [59 54 49 ... 64 64 64]]
# ./thermal2\1566904384279-temperatures.txt
# 29706.898125
# [[ 73  73  73 ...  73  76  76]
#  [ 74  73  73 ...  73  76  77]
#  [ 74  73  73 ...  73  74  77]
#  ...
#  [111 110 109 ...  70  70  70]
#  [111 110 109 ...  70  70  70]
#  [110 110 109 ...  70  70  70]]
# ./thermal2\1566904385334-temperatures.txt
# 29700.45131510417
# [[ 73  73  73 ...  64  65  66]
#  [ 71  73  73 ...  64  65  66]
#  [ 71  73  73 ...  64  65  66]
#  ...
#  [124 124 122 ...  75  75  75]
#  [124 124 122 ...  75  75  75]
#  [124 124 124 ...  75  75  75]]
# ./thermal2\1566904386399-temperatures.txt
# 29695.083125
# [[ 63  63  64 ...  60  61  63]
#  [ 63  63  64 ...  60  61  63]
#  [ 63  63  64 ...  60  61  63]
#  ...
#  [110 110 110 ...  70  70  70]
#  [110 110 110 ...  70  70  70]
#  [110 110 110 ...  70  70  70]]
# ./thermal2\1566904387433-temperatures.txt
# 29690.142239583332
# [[57 59 59 ... 54 54 54]
#  [57 59 59 ... 54 54 54]
#  [57 59 59 ... 54 54 54]
#  ...
#  [97 97 96 ... 65 65 65]
#  [97 97 96 ... 65 65 65]
#  [97 97 97 ... 65 65 65]]
# ./thermal2\1566904388472-temperatures.txt
# 29674.9703125
# [[50 51 51 ... 46 47 47]
#  [50 51 52 ... 46 47 49]
#  [50 52 52 ... 46 47 49]
#  ...
#  [99 99 99 ... 61 61 61]
#  [99 99 99 ... 61 61 61]
#  [99 99 98 ... 61 61 61]]
# ./thermal2\1566904389555-temperatures.txt
# 29667.210885416665
# [[56 57 57 ... 48 50 50]
#  [56 57 57 ... 48 50 51]
#  [56 58 58 ... 49 50 51]
#  ...
#  [98 98 98 ... 62 62 62]
#  [98 98 98 ... 62 62 62]
#  [98 98 98 ... 62 64 64]]
# ./thermal2\1566904390599-temperatures.txt
# 29659.601822916666
# [[52 52 53 ... 46 47 47]
#  [52 52 53 ... 46 47 48]
#  [52 52 53 ... 46 47 48]
#  ...
#  [95 95 95 ... 60 60 60]
#  [95 95 95 ... 60 60 60]
#  [95 95 95 ... 61 61 61]]
# ./thermal2\1566904391635-temperatures.txt
# 29651.162096354168
# [[ 48  48  48 ...  40  40  41]
#  [ 47  48  48 ...  40  40  42]
#  [ 47  48  48 ...  39  40  42]
#  ...
#  [100 100 100 ...  58  58  58]
#  [100 100 100 ...  58  58  58]
#  [100 100 100 ...  58  58  58]]
# ./thermal2\1566904392639-temperatures.txt
# 29646.893776041667
# [[49 50 50 ... 45 48 48]
#  [49 50 50 ... 45 48 49]
#  [49 50 50 ... 47 48 49]
#  ...
#  [99 99 99 ... 62 62 62]
#  [99 99 99 ... 62 62 62]
#  [99 99 99 ... 62 62 62]]
# ./thermal2\1566904393678-temperatures.txt
# 29638.707760416666
# [[45 46 46 ... 41 43 44]
#  [46 47 47 ... 43 44 44]
#  [46 48 48 ... 43 44 45]
#  ...
#  [96 96 96 ... 58 60 60]
#  [96 96 96 ... 58 60 60]
#  [96 96 95 ... 58 58 58]]
# ./thermal2\1566904394719-temperatures.txt
# 29635.565481770835
# [[50 50 50 ... 45 45 46]
#  [49 50 50 ... 45 45 46]
#  [49 50 50 ... 45 45 46]
#  ...
#  [90 90 90 ... 57 57 58]
#  [90 90 90 ... 57 57 58]
#  [90 90 90 ... 57 57 57]]
# ./thermal2\1566904395760-temperatures.txt
# 29632.878984375
# [[53 56 56 ... 46 47 48]
#  [53 56 57 ... 46 48 48]
#  [53 56 57 ... 46 48 48]
#  ...
#  [83 83 83 ... 48 48 48]
#  [83 83 83 ... 48 48 48]
#  [82 82 82 ... 48 48 48]]
# ./thermal2\1566904396800-temperatures.txt
# 29628.045286458335
# [[47 47 47 ... 38 39 39]
#  [47 47 47 ... 38 39 40]
#  [47 47 47 ... 38 39 40]
#  ...
#  [87 87 86 ... 53 53 53]
#  [87 87 86 ... 53 53 53]
#  [86 86 86 ... 53 53 53]]
# ./thermal2\1566904397843-temperatures.txt
# 29623.4605859375
# [[50 50 51 ... 47 49 49]
#  [49 50 51 ... 47 49 50]
#  [49 51 51 ... 47 49 50]
#  ...
#  [99 99 99 ... 63 63 63]
#  [99 99 99 ... 63 63 63]
#  [99 99 99 ... 62 62 62]]
# ./thermal2\1566904398882-temperatures.txt
# 29611.972200520835
# [[45 46 45 ... 46 47 47]
#  [46 46 46 ... 46 47 48]
#  [46 46 46 ... 46 47 48]
#  ...
#  [90 90 90 ... 56 56 56]
#  [90 90 90 ... 56 56 56]
#  [90 90 89 ... 56 56 56]]
# ./thermal2\1566904399930-temperatures.txt
# 29608.7627734375
# [[46 46 46 ... 44 44 44]
#  [44 46 46 ... 44 44 44]
#  [44 46 46 ... 44 44 44]
#  ...
#  [85 85 85 ... 53 53 53]
#  [85 85 85 ... 53 53 53]
#  [85 85 85 ... 53 53 53]]
# ./thermal2\1566904400958-temperatures.txt
# 29603.434544270833
# [[37 37 37 ... 33 34 35]
#  [37 37 37 ... 33 35 35]
#  [37 37 37 ... 33 35 35]
#  ...
#  [80 80 80 ... 49 49 49]
#  [80 80 80 ... 49 49 49]
#  [80 80 80 ... 49 49 49]]
# ./thermal2\1566904402051-temperatures.txt
# 29594.38408854167
# [[32 34 34 ... 30 30 30]
#  [32 34 34 ... 30 30 30]
#  [32 34 34 ... 30 30 30]
#  ...
#  [80 80 80 ... 48 48 48]
#  [80 80 80 ... 48 48 48]
#  [80 80 80 ... 48 48 48]]
# ./thermal2\1566904403129-temperatures.txt
# 29594.38408854167
# [[32 34 34 ... 30 30 30]
#  [32 34 34 ... 30 30 30]
#  [32 34 34 ... 30 30 30]
#  ...
#  [80 80 80 ... 48 48 48]
#  [80 80 80 ... 48 48 48]
#  [80 80 80 ... 48 48 48]]
# ./thermal2\1566904404164-temperatures.txt
# 29720.052369791665
# [[54 55 55 ... 62 64 65]
#  [53 54 54 ... 60 62 63]
#  [53 53 53 ... 58 59 60]
#  ...
#  [81 80 80 ... 53 51 51]
#  [81 81 80 ... 53 53 52]
#  [82 81 81 ... 54 53 53]]
# ./thermal2\1566904405252-temperatures.txt
# 29710.521861979167
# [[65 65 65 ... 63 64 64]
#  [64 65 65 ... 63 64 65]
#  [64 65 65 ... 62 64 65]
#  ...
#  [95 95 95 ... 62 62 62]
#  [95 95 95 ... 62 62 62]
#  [95 95 95 ... 62 62 62]]
# ./thermal2\1566904406320-temperatures.txt
# 29716.478802083333
# [[78 78 78 ... 78 78 79]
#  [77 77 77 ... 77 78 78]
#  [77 77 77 ... 77 77 78]
#  ...
#  [96 96 95 ... 64 64 64]
#  [96 96 95 ... 64 64 64]
#  [96 96 95 ... 64 64 64]]
# ./thermal2\1566904407364-temperatures.txt
# 29728.6044921875
# [[81 81 81 ... 74 74 74]
#  [81 81 81 ... 74 74 74]
#  [81 81 81 ... 73 74 74]
#  ...
#  [95 95 94 ... 61 61 61]
#  [95 95 94 ... 61 61 61]
#  [95 95 95 ... 61 61 61]]
# ./thermal2\1566904408403-temperatures.txt
# 29748.280377604166
# [[93 93 94 ... 91 93 94]
#  [93 93 93 ... 93 94 95]
#  [93 93 93 ... 93 94 95]
#  ...
#  [96 95 95 ... 64 64 64]
#  [96 95 95 ... 64 64 64]
#  [96 96 96 ... 64 64 64]]
# ./thermal2\1566904409445-temperatures.txt
# 29769.050416666665
# [[95 95 94 ... 91 92 93]
#  [94 94 94 ... 90 92 93]
#  [94 94 94 ... 90 92 93]
#  ...
#  [98 98 98 ... 63 63 63]
#  [98 98 98 ... 63 63 63]
#  [98 98 98 ... 64 64 64]]
# ./thermal2\1566904410481-temperatures.txt
# 29785.441783854167
# [[ 96  96  95 ...  92  93  94]
#  [ 96  96  95 ...  92  93  94]
#  [ 96  96  94 ...  91  92  94]
#  ...
#  [100 100  97 ...  69  69  69]
#  [100 100  99 ...  69  69  69]
#  [100 100 100 ...  69  69  69]]
# ./thermal2\1566904411551-temperatures.txt
# 29793.254466145834
# [[102 102 102 ...  96  96  98]
#  [102 101 101 ...  95  96  96]
#  [102 101 100 ...  94  96  96]
#  ...
#  [102 102 101 ...  66  66  66]
#  [102 102 102 ...  66  66  66]
#  [103 102 102 ...  68  68  68]]
# ./thermal2\1566904412564-temperatures.txt
# 29811.00420572917
# [[96 96 96 ... 87 88 89]
#  [96 96 96 ... 87 87 88]
#  [96 96 96 ... 86 87 88]
#  ...
#  [93 93 92 ... 67 67 67]
#  [93 93 93 ... 67 67 67]
#  [94 93 93 ... 68 69 69]]
# ./thermal2\1566904413608-temperatures.txt
# 29820.14203125
# [[110 110 109 ... 102 104 105]
#  [110 110 109 ... 102 104 105]
#  [110 110 109 ... 102 103 105]
#  ...
#  [105 105 104 ...  73  73  73]
#  [105 105 105 ...  73  73  73]
#  [107 105 105 ...  73  75  75]]
# ./thermal2\1566904414652-temperatures.txt
# 29825.582942708334
# [[116 114 114 ... 108 109 111]
#  [114 114 114 ... 108 109 111]
#  [114 114 114 ... 108 109 111]
#  ...
#  [109 109 108 ...  78  78  79]
#  [109 109 109 ...  78  79  79]
#  [111 111 111 ...  79  79  79]]
# ./thermal2\1566904415691-temperatures.txt
# 29828.471119791666
# [[110 110 109 ... 104 105 106]
#  [110 109 109 ... 104 105 105]
#  [110 109 109 ... 103 104 105]
#  ...
#  [109 109 108 ...  73  73  73]
#  [110 110 109 ...  73  73  73]
#  [110 110 110 ...  73  73  73]]
# ./thermal2\1566904416729-temperatures.txt
# 29832.0287890625
# [[109 109 109 ... 103 104 104]
#  [109 109 108 ... 101 104 104]
#  [109 108 108 ... 101 103 104]
#  ...
#  [109 108 107 ...  68  70  70]
#  [109 108 108 ...  68  70  70]
#  [108 108 108 ...  70  70  70]]
# ./thermal2\1566904417766-temperatures.txt
# 29832.0473828125
# [[116 116 116 ... 109 111 111]
#  [116 116 116 ... 109 111 112]
#  [116 116 116 ... 109 111 112]
#  ...
#  [117 117 117 ...  73  73  73]
#  [119 119 119 ...  73  73  73]
#  [119 120 119 ...  73  73  73]]
# ./thermal2\1566904418808-temperatures.txt
# 29830.220286458334
# [[116 116 115 ... 108 108 110]
#  [116 116 115 ... 107 108 108]
#  [116 115 115 ... 106 108 108]
#  ...
#  [119 117 116 ...  75  75  75]
#  [119 117 116 ...  75  75  75]
#  [119 117 117 ...  75  75  75]]
# ./thermal2\1566904419849-temperatures.txt
# 29831.3769140625
# [[115 115 115 ... 108 111 112]
#  [115 115 115 ... 108 111 112]
#  [115 115 115 ... 108 110 112]
#  ...
#  [121 120 120 ...  81  81  81]
#  [121 121 120 ...  81  81  81]
#  [122 121 121 ...  81  81  81]]
# ./thermal2\1566904420890-temperatures.txt
# 29828.719166666666
# [[107 107 106 ... 109 110 113]
#  [107 107 106 ... 109 111 114]
#  [107 106 106 ... 110 113 115]
#  ...
#  [123 123 122 ...  85  86  86]
#  [123 123 122 ...  86  86  86]
#  [123 123 122 ...  88  88  88]]
# ./thermal2\1566904421969-temperatures.txt
# 29820.8077734375
# [[ 95  95  95 ...  95  97  99]
#  [ 95  95  93 ...  95  97  99]
#  [ 95  95  93 ...  95  96  99]
#  ...
#  [116 116 116 ...  80  80  80]
#  [116 116 116 ...  80  80  80]
#  [116 116 116 ...  80  80  80]]
# ./thermal2\1566904423055-temperatures.txt
# 29814.928111979167
# [[ 94  94  94 ...  92  94  94]
#  [ 94  94  93 ...  92  94  96]
#  [ 94  94  93 ...  92  94  96]
#  ...
#  [120 120 120 ...  80  80  80]
#  [120 120 120 ...  80  80  80]
#  [120 120 120 ...  80  80  80]]
# ./thermal2\1566904424090-temperatures.txt
# 29812.999505208332
# [[ 81  81  81 ...  88  90  90]
#  [ 79  79  79 ...  88  90  90]
#  [ 79  79  79 ...  88  90  90]
#  ...
#  [101 101 100 ...  67  67  67]
#  [101 101 100 ...  67  67  67]
#  [101 101 101 ...  67  67  67]]
# ./thermal2\1571313531573-temperatures.txt
# 29555.018033854165
# [[ 83  83  83 ...  69  70  70]
#  [ 83  83  83 ...  69  70  71]
#  [ 83  83  83 ...  70  71  71]
#  ...
#  [120 120 119 ...  16  17  17]
#  [121 121 120 ...  16  17  17]
#  [122 121 121 ...  16  17  17]]
# ./thermal2\1571313541052-temperatures.txt
# 29703.562604166666
# [[76 76 76 ... 22 23 23]
#  [76 76 76 ... 22 23 23]
#  [76 76 76 ... 23 23 23]
#  ...
#  [78 78 77 ... 71 71 71]
#  [78 78 78 ... 71 71 71]
#  [78 78 78 ... 71 71 72]]
# ./thermal2\1571313624064-temperatures.txt
# 29105.7673046875
# [[ 85  85  85 ...  97 104 114]
#  [ 85  85  86 ...  97 105 114]
#  [ 85  86  86 ...  98 105 114]
#  ...
#  [105 105 106 ...  21  22  23]
#  [106 106 106 ...  21  22  23]
#  [106 106 106 ...  21  22  23]]
# ./thermal2\1571313651120-temperatures.txt
# 29480.226536458333
# [[ 92  93  93 ...  22  22  23]
#  [ 92  93  93 ...  22  22  22]
#  [ 92  93  93 ...  22  22  22]
#  ...
#  [100 100 101 ... 109 109 110]
#  [ 99 100 100 ... 108 109 109]
#  [ 99 100 100 ... 108 109 109]]

# %%
import glob
import cv2
import numpy as np
filelist=glob.glob('./threshold-thermal2/*.png')
image_number = 0
for i in filelist:
    image = cv2.imread(i)
    original = image.copy()
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    canny = cv2.Canny(blurred, 120, 255, 1)
    kernel = np.ones((5,5),np.uint8)
    dilate = cv2.dilate(canny, kernel, iterations=1)

    # Find contours
    cnts = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]

    # Iterate thorugh contours and filter for ROI
   
    for c in cnts:
        x,y,w,h = cv2.boundingRect(c)
        cv2.rectangle(image, (x, y), (x + w, y + h), (36,255,12), 2)
        ROI = original[y:y+h, x:x+w]
        cv2.imwrite("{} ROI.png".format(image_number), ROI)
        image_number += 1
        area = cv2.contourArea(c)
        #print(area)
    
    #cv2.imshow('canny', canny)
    #cv2.imshow('image', image)
    #cv2.waitKey(0)

# %%
# Imports
import random, cv2, os, sys, shutil
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
import keras
import csv
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# Out:
# Using TensorFlow backend.

# %%
class image_clustering:

    def __init__(self, folder_path="data", n_clusters=3, max_examples=500, use_imagenets=False, use_pca=False):
        paths = os.listdir(folder_path)
        if max_examples == None:
            self.max_examples = len(paths)
        else:
            if max_examples > len(paths):
                self.max_examples = len(paths)
            else:
                self.max_examples = max_examples
        self.n_clusters = n_clusters
        self.folder_path = folder_path
        random.shuffle(paths)
        self.image_paths = paths[:self.max_examples]
        self.use_imagenets = use_imagenets
        self.use_pca = use_pca
        del paths 
        try:
            shutil.rmtree("output")
        except FileExistsError:
            pass
        print("\n output folders created.")
        os.makedirs("output")
        for i in range(self.n_clusters):
            os.makedirs("output\\cluster" + str(i))
        print("\n Object of class \"image_clustering\" has been initialized.")

    def load_images(self):
        self.images = []
        for image in self.image_paths:
            self.images.append(cv2.cvtColor(cv2.resize(cv2.imread(self.folder_path + "\\" + image), (224,224)), cv2.COLOR_BGR2RGB))
        self.images = np.float32(self.images).reshape(len(self.images),-1)
        self.images /= 255
        print("\n " + str(self.max_examples) + " images from the \"" + self.folder_path + "\" folder have been loaded in a random order.")

    def get_new_imagevectors(self):
        if self.use_imagenets == False:
            self.images_new = self.images
        else:
            if use_imagenets.lower() == "vgg16":
                model1 = keras.applications.vgg19.vgg19(include_top=False, weights="imagenet", input_shape=(224,224,3))
            elif use_imagenets.lower() == "vgg19":
                model1 = keras.applications.vgg19.vgg19(include_top=False, weights="imagenet", input_shape=(224,224,3))
            elif use_imagenets.lower() == "resnet50":
                model1 = keras.applications.resnet50.ResNet50(include_top=False, weights="imagenet", input_shape=(224,224,3))
            elif use_imagenets.lower() == "xception":
                model1 = keras.applications.xception.Xception(include_top=False, weights='imagenet',input_shape=(224,224,3))
            elif use_imagenets.lower() == "inceptionv3":
                model1 = keras.applications.inception_v3.InceptionV3(include_top=False, weights='imagenet', input_shape=(224,224,3))
            elif use_imagenets.lower() == "inceptionresnetv2":
                model1 = keras.applications.inception_resnet_v2.InceptionResNetV2(include_top=False, weights='imagenet', input_shape=(224,224,3))
            elif use_imagenets.lower() == "densenet":
                model1 = keras.applications.densenet.DenseNet201(include_top=False, weights='imagenet', input_shape=(224,224,3))
            elif use_imagenets.lower() == "mobilenetv2":
                model1 = keras.applications.mobilenetv2.MobileNetV2(input_shape=(224,224,3), alpha=1.0, depth_multiplier=1, include_top=False, weights='imagenet', pooling=None)
            else:
                print("\n\n Please use one of the following keras applications only [ \"vgg16\", \"vgg19\", \"resnet50\", \"xception\", \"inceptionv3\", \"inceptionresnetv2\", \"densenet\", \"mobilenetv2\" ] or False")
                sys.exit()

            pred = model1.predict(self.images)
            images_temp = pred.reshape(self.images.shape[0], -1)
            if self.use_pca == False: 
                self.images_new = images_temp
            else: 
                model2 = PCA(n_components=None, random_state=728)
                model2.fit(images_temp)
                self.images_new = model2

    def clustering(self):
        estimator = KMeans(n_clusters=self.n_clusters, n_jobs=-1, random_state=728)
        estimator.fit(self.images_new)
        predictions = estimator.predict(self.images_new)
        np.savetxt("predictions.csv", predictions, delimiter=",", fmt='%s', header=header)
        predictions1= estimator.transform(self.images_new)
        np.savetxt("predictions1.csv", predictions1, delimiter=",", fmt='%s', header=header)
        #predicarray = np.array(predictions1)
        #print(model.inertia_)
        cluster0=[]
        cluster1=[]
        cluster2=[]
        cluster3=[]
        p0=[]
        p1=[]
        p2=[]
        p3=[]
        #for i in predictions:
        #    if predictions[i]==0:
        #        #print (predictions[i])
        #        p0.append(predictions1[])
        #        cluster0.append(p0[0][i])
        #        #print(predictions1[:, 0])
        #for i in predictions:
        #    if predictions[i]==1:
        #        #print (predictions[i])
        #        p1.append(predictions1[0][i])
        #        cluster1.append(p1[0][i])
        #        #print(predictions1[:, 0])
        #for i in predictions:
        #    if predictions[i]==2:
        #        #print (predictions[i])
        #        p2.append(predictions1[0][i])
        #        cluster2.append(p2[0][i])
        #        #print(predictions1[:, 0])
        #for i in predictions:
        #    if predictions[i]==3:
        #        #print (predictions[i])
        #        p3.append(predictions1[0][i])
        #        cluster3.append(p3[0][i])
        #        #print(predictions1[:, 0])
        #print(cluster0)
        #print(cluster1)
        #print(cluster2)
        #print(cluster3)
        #print(predictions)
        for i in range(self.max_examples):
            shutil.copy2(self.folder_path+"\\"+self.image_paths[i], "output\cluster"+str(predictions[i]))
        print("\n Clustering complete! \n\n Clusters and the respective images are stored in the \"output\" folder.")
        #empty dictionaries

        print("shape of prediction: " + str(predictions1.shape))
        clusters_centroids=dict()
        clusters_radii= dict()
        for cluster in range(0,self.n_clusters):

            clusters_centroids[cluster]=list(zip(estimator.cluster_centers_[:, 0],estimator.cluster_centers_[:,1]))[cluster]
            clusters_radii[cluster] = max([np.linalg.norm(np.subtract(i,clusters_centroids[cluster])) for i in zip(self.images_new[predictions == cluster, 0],self.images_new[predictions == cluster, 1])])
        
        #Visualising the clusters and cluster circles

        fig, ax = plt.subplots(1,figsize=(7,5))

        plt.scatter(self.images_new[predictions == 0, 0], self.images_new[predictions == 0, 0], s = 100, c = 'red', label = 'Cluster 1')
        art = mpatches.Circle(clusters_centroids[0],clusters_radii[0], edgecolor='r',fill=False)
        ax.add_patch(art)

        plt.scatter(self.images_new[predictions == 1, 0], self.images_new[predictions == 1, 0], s = 100, c = 'blue', label = 'Cluster 2')
        art = mpatches.Circle(clusters_centroids[1],clusters_radii[1], edgecolor='b',fill=False)
        ax.add_patch(art)

        plt.scatter(self.images_new[predictions == 2, 0], self.images_new[predictions == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
        art = mpatches.Circle(clusters_centroids[2],clusters_radii[2], edgecolor='g',fill=False)
        ax.add_patch(art)

        #Plotting the centroids of the clusters
        plt.scatter(estimator.cluster_centers_[:, 0], estimator.cluster_centers_[:,1], s = 100, c = 'yellow', label = 'Centroids')

        plt.legend()
        plt.tight_layout()
        plt.savefig('kmeans.jpg',dpi=300)
        print(clusters_centroids)
        print(clusters_radii)

# %%
if __name__ == "__main__":

	print("\n\n \t\t START\n\n")

	number_of_clusters = 4 # cluster names will be 0 to number_of_clusters-1

	data_path = "C:/Users/dar/Desktop/Unsupervised-Object-Clustering-master/ROI" # path of the folder that contains the images to be considered for the clustering (The folder must contain only image files)

	max_examples = 500 # number of examples to use, if "None" all of the images will be taken into consideration for the clustering
	# If the value is greater than the number of images present  in the "data_path" folder, it will use all the images and change the value of this variable to the number of images available in the "data_path" folder. 

	use_imagenets = False
	# choose from: "Xception", "VGG16", "VGG19", "ResNet50", "InceptionV3", "InceptionResNetV2", "DenseNet", "MobileNetV2" and "False" -> Default is: False
	# you have to use the correct spelling! (case of the letters are irrelevant as the lower() function has been used)

	if use_imagenets == False:
		use_pca = False
	else:
		use_pca = False # Make it True if you want to use PCA for dimentionaity reduction -> Default is: False

	temp = image_clustering(data_path, number_of_clusters, max_examples, use_imagenets, use_pca)
	temp.load_images()
	temp.get_new_imagevectors()
	temp.clustering()

	print("\n\n\t\t END\n\n")
# Out:
#  		 START
#
#
#
#  output folders created.
#
#  Object of class "image_clustering" has been initialized.
#
#  183 images from the "C:/Users/dar/Desktop/Unsupervised-Object-Clustering-master/ROI" folder have been loaded in a random order.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3b0b85c91b75> in <module>
#      22         temp.load_images()
#      23         temp.get_new_imagevectors()
# ---> 24         temp.clustering()
#      25
#      26         print("\n\n\t\t END\n\n")
#
# <ipython-input-4-3eaa4a4a2750> in clustering(self)
#      72         estimator.fit(self.images_new)
#      73         predictions = estimator.predict(self.images_new)
# ---> 74         np.savetxt("predictions.csv", predictions, delimiter=",", fmt='%s', header=header)
#      75         predictions1= estimator.transform(self.images_new)
#      76         np.savetxt("predictions1.csv", predictions1, delimiter=",", fmt='%s', header=header)
#
# NameError: name 'header' is not defined

# %%
filelist=glob.glob('C:/Users/dar/Desktop/Segmentation/output/cluster3/*.png')
areas=[]
for i in filelist:
    #image = cv2.imread(i)
    image = cv2.imread(i)
    original = image.copy()
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    canny = cv2.Canny(blurred, 120, 255, 1)
    kernel = np.ones((5,5),np.uint8)
    dilate = cv2.dilate(canny, kernel, iterations=1)
    cnts = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    for c in cnts:
        area = cv2.contourArea(c)
        #print(area)
        areas.append(area)
print(areas)
#with open('imagearea.csv', mode='a') as csv_file:
    #fieldnames = ['Image Name', 'Area']
    #writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    #writer.writeheader()
    #writer.writerow({'Image Name': i, 'Area': areas})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-e7c94d47c328> in <module>
# ----> 1 filelist=glob.glob('C:/Users/dar/Desktop/Segmentation/output/cluster3/*.png')
#       2 areas=[]
#       3 for i in filelist:
#       4     #image = cv2.imread(i)
#       5     image = cv2.imread(i)
#
# NameError: name 'glob' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fe46fb05d692> in <module>
#       2 import numpy as np
#       3 import os
# ----> 4 import core
#       5 import pickle
#       6 import warnings
#
# ModuleNotFoundError: No module named 'core'

# %%
# Out:
#  		 START
#
#
#
#  output folders created.
#
#  Object of class "image_clustering" has been initialized.
#
#  183 images from the "C:/Users/dar/Desktop/Segmentation/ROI" folder have been loaded in a random order.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b639cc5e8205> in <module>
#      21         temp = image_clustering(data_path, number_of_clusters, max_examples, use_imagenets, use_pca)
#      22         temp.load_images()
# ---> 23         temp.get_new_imagevectors()
#      24         temp.clustering()
#      25
#
# <ipython-input-6-63b2b6d6c3d6> in get_new_imagevectors(self)
#      59                                 sys.exit()
#      60
# ---> 61                         pred = model1.predict(self.images)
#      62                         images_temp = pred.reshape(self.images.shape[0], -1)
#      63                         if self.use_pca == False:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1439
#    1440         # Case 2: Symbolic tensors or Numpy array-like.
# -> 1441         x, _, _ = self._standardize_user_data(x)
#    1442         if self.stateful:
#    1443             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     577             feed_input_shapes,
#     578             check_batch_axis=False,  # Don't enforce the batch size.
# --> 579             exception_prefix='input')
#     580
#     581         if y is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     133                         ': expected ' + names[i] + ' to have ' +
#     134                         str(len(shape)) + ' dimensions, but got array '
# --> 135                         'with shape ' + str(data_shape))
#     136                 if not check_batch_axis:
#     137                     data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected input_1 to have 4 dimensions, but got array with shape (183, 150528)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-1e9451fb0829> in <module>
#       7 from PIL import Image as pimg
#       8 import matplotlib.pyplot as plt
# ----> 9 from neupy import algorithms, environment
#      10 from keras.applications.vgg16 import VGG16
#      11 from keras.preprocessing import image
#
# ModuleNotFoundError: No module named 'neupy'

# %%
for c in cnts:
        (x,y),radius = cv2.minEnclosingCircle(c)
        center = (int(x),int(y))
        radius = int(radius)
        img = cv2.circle(image,center,radius,(0,255,0),2)
        ROI = original[y:y, x:x]
        print('Contour: centre {},{}, radius {}'.format(x,y,radius))
